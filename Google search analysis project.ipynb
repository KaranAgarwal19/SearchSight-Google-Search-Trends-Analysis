# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pytrends.request import TrendReq

# %% [markdown]
# # setup pytrends library and keyword define

# %%
pytrends=TrendReq(hl='en-US',tz=360)
keyword="software engineer"

# %% [markdown]
# # Data Request

# %%
pytrends.build_payload([keyword],cat=0,timeframe='today 12-m',geo='',gprop='')

# %% [markdown]
# # country wise interest

# %%
region_data=pytrends.interest_by_region()
region_data=region_data.sort_values(by=keyword,ascending=False).head(15)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=region_data[keyword],y=region_data.index,palette="Blues_d")
plt.title(f"Top Countries searching for'{keyword}' ")
plt.xlabel("Interest")
plt.ylabel("Country")

plt.show()
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_12200\2749097791.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 5
#       3 plt.title(f"Top Countries searching for'{keyword}' ")
#       4 plt.xlabel("Interest")
# ----> 5 plt.ylabel("Country")
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # World map

# %%
region_data=region_data.reset_index()
fig=px.choropleth(region_data,
                  locations='geoName',
                  locationmode='country names',
                  color=keyword,
                  title=f"Search Interest for '{keyword}' by country",
                  color_continuous_scale='Blues')

fig.show()

# %% [markdown]
# # Time wise interest

# %%
time_df=pytrends.interest_over_time()
# Out:
# C:\Users\karan\anaconda3\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
plt.figure(figsize=(12,6))
plt.plot(time_df.index,time_df[keyword],marker='o',color='purple')
plt.title(f"Search interest over time '{keyword}' ")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 5
#       3 plt.title(f"Search interest over time '{keyword}' ")
#       4 plt.xlabel("Date")
# ----> 5 plt.ylabel("Interest")
#       6 plt.grid(True)
#       8 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Multiple keywords comparison

# %%
kw_list=["cloud computing", "data science ","web development"]
pytrends.build_payload(kw_list,cat=0,timeframe='today 12-m',geo='',gprop='')

# %%
compare_df=pytrends.interest_over_time()

plt.figure(figsize=(12,6))
for kw in kw_list:
    plt.plot(compare_df.index,compare_df[kw],label=kw)

plt.title("Keyword comparison over time")
plt.xlabel("Date")
plt.ylabel=("Interest")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# C:\Users\karan\anaconda3\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
